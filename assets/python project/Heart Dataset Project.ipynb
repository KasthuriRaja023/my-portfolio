# %% [markdown]
# Heart Failure and Clinical DataSet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Here We have Imported the Needed Packages to Do the EDA Process and To Visualize the Dataset.

# %%
heart = pd.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
heart
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0    75.0        0   582         0                 20                    1
# 1    55.0        0  7861         0                 38                    0
# 2    65.0        0   146         0                 20                    0
# 3    50.0        1   111         0                 20                    0
# 4    65.0        1   160         1                 20                    0
# ..    ...      ...   ...       ...                ...                  ...
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 296  45.0        0  2060         1                 60                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
# ...

# %%
heart.columns
# Out:
# Index(['age', 'anaemia', 'cpk', 'diabetes', 'ejection_fraction',
#        'high_blood_pressure', 'platelets', 'serum_creatinine', 'serum_sodium',
#        'sex', 'smoking', 'time', 'death_event'],
#       dtype='object')

# %%
heart.head()
# Out:
#     age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0  75.0        0   582         0                 20                    1
# 1  55.0        0  7861         0                 38                    0
# 2  65.0        0   146         0                 20                    0
# 3  50.0        1   111         0                 20                    0
# 4  65.0        1   160         1                 20                    0
#
#    platelets  serum_creatinine  serum_sodium     sex  smoking  time  \
# 0     265000               1.9           130    Male        0     4
# 1     263358               1.1           136    Male        0     6
# 2     162000               1.3           129    Male        1     7
# 3     210000               1.9           137    Male        0     7
# 4     327000               2.7           116  Female        0     8
#
#    death_event
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
heart.tail()
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 296  45.0        0  2060         1                 60                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
#      platelets  serum_creatinine  serum_sodium     sex  smoking  time  \
# 294     155000               1.1           143    Male        1   270
# 295     270000               1.2           139  Female        0   271
# 296     742000               0.8           138  Female        0   278
# 297     140000               1.4           140    Male        1   280
# 298     395000               1.6           136    Male        1   285
#
#      death_event
# 294            0
# 295            0
# 296            0
# 297            0
# ...

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  299 non-null    float64
#  1   anaemia              299 non-null    int64
#  2   cpk                  299 non-null    int64
#  3   diabetes             299 non-null    int64
#  4   ejection_fraction    299 non-null    int64
#  5   high_blood_pressure  299 non-null    int64
#  6   platelets            299 non-null    int64
#  7   serum_creatinine     299 non-null    float64
#  8   serum_sodium         299 non-null    int64
#  9   sex                  299 non-null    object
#  10  smoking              299 non-null    int64
#  11  time                 299 non-null    int64
#  12  death_event          299 non-null    int64
# dtypes: float64(2), int64(10), object(1)
# memory usage: 30.5+ KB

# %%
heart.shape
# Out:
# (284, 13)

# %%
heart.describe()
# Out:
#               age     anaemia          cpk    diabetes  ejection_fraction  \
# count  299.000000  299.000000   299.000000  299.000000         299.000000
# mean    60.833893    0.431438   581.839465    0.418060          38.083612
# std     11.894809    0.496107   970.287881    0.494067          11.834841
# min     40.000000    0.000000    23.000000    0.000000          14.000000
# 25%     51.000000    0.000000   116.500000    0.000000          30.000000
# 50%     60.000000    0.000000   250.000000    0.000000          38.000000
# 75%     70.000000    1.000000   582.000000    1.000000          45.000000
# max     95.000000    1.000000  7861.000000    1.000000          80.000000
#
#        high_blood_pressure      platelets  serum_creatinine  serum_sodium  \
# count           299.000000     299.000000         299.00000    299.000000
# mean              0.351171  263358.026756           1.39388    136.625418
# std               0.478136   97804.236869           1.03451      4.412477
# ...

# %%
heart.isnull().sum()
# Out:
# age                    0
# anaemia                0
# cpk                    0
# diabetes               0
# ejection_fraction      0
# high_blood_pressure    0
# platelets              0
# serum_creatinine       0
# serum_sodium           0
# sex                    0
# smoking                0
# time                   0
# death_event            0
# dtype: int64

# %%
heart.mean()
# Out:
# C:\Users\kasth\AppData\Local\Temp\ipykernel_20444\301479055.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   heart.mean()
# age                        60.833893
# anaemia                     0.431438
# cpk                       581.839465
# diabetes                    0.418060
# ejection_fraction          38.083612
# high_blood_pressure         0.351171
# platelets              263358.026756
# serum_creatinine            1.393880
# serum_sodium              136.625418
# smoking                     0.321070
# time                      130.260870
# death_event                 0.321070
# dtype: float64

# %% [markdown]
# **Chart**

# %%
plt.figure(figsize=(20,15))
sns.heatmap(heart.corr(),cbar=True,annot=True,cmap='Reds')
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='sex', y='smoking', data=heart,hue='sex');

# %%
plt.hist(heart.age,bins=5)
# Out:
# (array([74., 94., 86., 31., 14.]),
#  array([40., 51., 62., 73., 84., 95.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(heart.cpk)
# Out:
# (array([252.,  21.,  13.,   6.,   0.,   3.,   1.,   1.,   0.,   2.]),
#  array([  23. ,  806.8, 1590.6, 2374.4, 3158.2, 3942. , 4725.8, 5509.6,
#         6293.4, 7077.2, 7861. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(heart.platelets,bins=5)
# Out:
# (array([ 55., 203.,  36.,   3.,   2.]),
#  array([ 25100., 190080., 355060., 520040., 685020., 850000.]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(heart.serum_creatinine,bins=5)
# Out:
# (array([271.,  21.,   3.,   2.,   2.]),
#  array([0.5 , 2.28, 4.06, 5.84, 7.62, 9.4 ]),
#  <BarContainer object of 5 artists>)

# %%
sns.boxplot(x='age',data=heart)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x='cpk',data=heart)
# Out:
# <AxesSubplot:xlabel='cpk'>

# %%
sns.boxplot(x='platelets',data=heart)
# Out:
# <AxesSubplot:xlabel='platelets'>

# %%
heart[heart['platelets']>=450000]
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 7    60.0        1   315         1                 60                    0
# 47   60.0        0   582         1                 38                    1
# 55   95.0        1   371         0                 30                    0
# 69   65.0        0   113         1                 25                    0
# 105  72.0        1   328         0                 30                    1
# 109  45.0        0   292         1                 35                    0
# 117  85.0        1   102         0                 60                    0
# 212  78.0        0   224         0                 50                    0
# 224  58.0        0   582         1                 25                    0
# 240  70.0        0    81         1                 35                    1
# 279  55.0        0    84         1                 38                    0
# ...

# %%
heart = heart[heart['platelets']<450000]

# %%
sns.boxplot(x='platelets',data=heart)
plt.show()

# %%
sns.boxplot(x='serum_sodium',data=heart)
# Out:
# <AxesSubplot:xlabel='serum_sodium'>

# %%
sns.boxplot(x = heart.ejection_fraction, color = 'teal')
plt.show()

# %%
heart[heart['ejection_fraction']>=70]
# Out:
#       age  anaemia  cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 64   45.0        0  582         0                 80                    0
# 217  54.0        1  427         0                 70                    1
#
#      platelets  serum_creatinine  serum_sodium     sex  smoking  time  \
# 64      263358              1.18           137  Female        0    63
# 217     151000              9.00           137  Female        0   196
#
#      death_event
# 64             0
# 217            1

# %%
heart = heart[heart['ejection_fraction']<70]

# %%
sns.boxplot(x = heart.ejection_fraction, color = 'teal')
plt.show()

# %%
heart
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0    75.0        0   582         0                 20                    1
# 1    55.0        0  7861         0                 38                    0
# 2    65.0        0   146         0                 20                    0
# 3    50.0        1   111         0                 20                    0
# 4    65.0        1   160         1                 20                    0
# ..    ...      ...   ...       ...                ...                  ...
# 293  63.0        1   103         1                 35                    0
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
# ...

# %%
sns.distplot(heart.age, kde=True)
# Out:
# c:\Users\kasth\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
heart
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0    75.0        0   582         0                 20                    1
# 1    55.0        0  7861         0                 38                    0
# 2    65.0        0   146         0                 20                    0
# 3    50.0        1   111         0                 20                    0
# 4    65.0        1   160         1                 20                    0
# ..    ...      ...   ...       ...                ...                  ...
# 293  63.0        1   103         1                 35                    0
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
# ...

# %%
sns.barplot(x='sex', y='death_event', data=heart,hue='sex');

# %%
heart
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0    75.0        0   582         0                 20                    1
# 1    55.0        0  7861         0                 38                    0
# 2    65.0        0   146         0                 20                    0
# 3    50.0        1   111         0                 20                    0
# 4    65.0        1   160         1                 20                    0
# ..    ...      ...   ...       ...                ...                  ...
# 293  63.0        1   103         1                 35                    0
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
# ...

# %%
sns.barplot(x='high_blood_pressure', y='age', data=heart,hue='sex');

# %%
heart
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0    75.0        0   582         0                 20                    1
# 1    55.0        0  7861         0                 38                    0
# 2    65.0        0   146         0                 20                    0
# 3    50.0        1   111         0                 20                    0
# 4    65.0        1   160         1                 20                    0
# ..    ...      ...   ...       ...                ...                  ...
# 293  63.0        1   103         1                 35                    0
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
# ...

# %%
sns.barplot(x='high_blood_pressure', y='age', data=heart,hue='sex');

# %%
heart
# Out:
#       age  anaemia   cpk  diabetes  ejection_fraction  high_blood_pressure  \
# 0    75.0        0   582         0                 20                    1
# 1    55.0        0  7861         0                 38                    0
# 2    65.0        0   146         0                 20                    0
# 3    50.0        1   111         0                 20                    0
# 4    65.0        1   160         1                 20                    0
# ..    ...      ...   ...       ...                ...                  ...
# 293  63.0        1   103         1                 35                    0
# 294  62.0        0    61         1                 38                    1
# 295  55.0        0  1820         0                 38                    0
# 297  45.0        0  2413         0                 38                    0
# 298  50.0        0   196         0                 45                    0
#
# ...

# %%
sns.barplot(x='death_event', y='serum_creatinine', data=heart,hue='sex');

# %%
sns.barplot(x='death_event', y='age', data=heart,hue='sex');
